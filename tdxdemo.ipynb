# %%
import numpy as np 
import pandas as pd 
from tqcenter import tq
import time
import json
# Out:
# Running cells with 'Python' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/new_tdx_mock/PYPlugins/user/.venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df = tq.get_market_data(
        field_list=[],
        stock_list=['00144.HK'],
        start_time='',
        end_time='',
        count=1,
        dividend_type='none',
        period='1d',
        fill_data=False
    )
print(df)
# Out:
# {'ForwardFactor':             00144.HK
# 2026-03-27       0.0, 'High':             00144.HK
# 2026-03-27     15.85, 'Low':             00144.HK
# 2026-03-27     15.51, 'Amount':             00144.HK
# 2026-03-27   3218.44, 'Open':             00144.HK
# 2026-03-27     15.76, 'Close':             00144.HK
# 2026-03-27     15.72, 'Volume':             00144.HK
# 2026-03-27   20487.0}

# %%
tq.close()
# Out:
# TQ数据连接已关闭
